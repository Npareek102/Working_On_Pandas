# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/paree/Documents/GermanCreditDataset/SouthGermanCredit.asc', sep=" ")

# %%
print(df.shape)
# Out:
# (1000, 21)

# %%
print(df.columns)
# Out:
# Index(['laufkont', 'laufzeit', 'moral', 'verw', 'hoehe', 'sparkont', 'beszeit',
#        'rate', 'famges', 'buerge', 'wohnzeit', 'verm', 'alter', 'weitkred',
#        'wohn', 'bishkred', 'beruf', 'pers', 'telef', 'gastarb', 'kredit'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# laufkont    int64
# laufzeit    int64
# moral       int64
# verw        int64
# hoehe       int64
# sparkont    int64
# beszeit     int64
# rate        int64
# famges      int64
# buerge      int64
# wohnzeit    int64
# verm        int64
# alter       int64
# weitkred    int64
# wohn        int64
# bishkred    int64
# beruf       int64
# pers        int64
# telef       int64
# gastarb     int64
# kredit      int64
# dtype: object

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0           1        18      4     2   1049         1        2     4       2
# 1           1         9      4     0   2799         1        3     2       3
# 2           2        12      2     9    841         2        4     2       2
# 3           1        12      4     0   2122         1        3     3       3
# 4           1        12      4     0   2171         1        3     4       3
# ..        ...       ...    ...   ...    ...       ...      ...   ...     ...
# 995         1        24      2     3   1987         1        3     2       3
# 996         1        24      2     0   2303         1        5     4       3
# 997         4        21      4     0  12680         5        5     4       3
# 998         2        12      2     3   6468         5        1     2       3
# 999         1        30      2     2   6350         5        5     4       3
#
# ...

# %%
print(df.head())
# Out:
#    laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0         1        18      4     2   1049         1        2     4       2
# 1         1         9      4     0   2799         1        3     2       3
# 2         2        12      2     9    841         2        4     2       2
# 3         1        12      4     0   2122         1        3     3       3
# 4         1        12      4     0   2171         1        3     4       3
#
#    buerge  ...  verm  alter  weitkred  wohn  bishkred  beruf  pers  telef  \
# 0       1  ...     2     21         3     1         1      3     2      1
# 1       1  ...     1     36         3     1         2      3     1      1
# 2       1  ...     1     23         3     1         1      2     2      1
# 3       1  ...     1     39         3     1         2      2     1      1
# 4       1  ...     2     38         1     2         2      2     2      1
#
#    gastarb  kredit
# 0        2       1
# 1        2       1
# ...

# %%
subset = df.loc[:, ['laufzeit', 'hoehe']]

# %%
print(subset.head())
# Out:
#    laufzeit  hoehe
# 0        18   1049
# 1         9   2799
# 2        12    841
# 3        12   2122
# 4        12   2171

# %%
df['alter'].head()
# Out:
# 0    21
# 1    36
# 2    23
# 3    39
# 4    38
# Name: alter, dtype: int64

# %%
df['alter'].tail()
# Out:
# 995    21
# 996    45
# 997    30
# 998    52
# 999    31
# Name: alter, dtype: int64

# %%
df[df['alter'] > 50].head()
# Out:
#     laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 8          4        18      4     3   1098         1        1     4       2
# 25         2        11      3     3   4771         1        4     2       3
# 29         3        42      4     1   4796         1        5     4       3
# 41         1        24      2    10   1755         1        5     4       2
# 44         2        18      2     6   1239         5        3     4       3
#
#     buerge  ...  verm  alter  weitkred  wohn  bishkred  beruf  pers  telef  \
# 8        1  ...     3     65         3     2         2      1     2      1
# 25       1  ...     2     51         3     2         1      3     2      1
# 29       1  ...     4     56         3     3         1      3     2      1
# 41       3  ...     1     58         3     2         1      2     2      2
# 44       1  ...     4     61         3     3         1      3     2      1
#
#     gastarb  kredit
# 8         2       1
# ...

# %%
df[(df['alter'] > 50) & (df['hoehe'] > 4000)].head()
# Out:
#      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 25          2        11      3     3   4771         1        4     2       3
# 29          3        42      4     1   4796         1        5     4       3
# 103         2        36      3     0   7432         1        3     2       2
# 158         2        48      1     9   6416         1        5     4       2
# 167         4        24      4     9   4526         1        3     3       3
#
#      buerge  ...  verm  alter  weitkred  wohn  bishkred  beruf  pers  telef  \
# 25        1  ...     2     51         3     2         1      3     2      1
# 29        1  ...     4     56         3     3         1      3     2      1
# 103       1  ...     2     54         3     1         1      3     2      1
# 158       1  ...     4     59         3     1         1      3     2      1
# 167       1  ...     1     74         3     2         1      4     2      2
#
#      gastarb  kredit
# 25         2       1
# ...

# %%
df['kredit'].value_counts()
# Out:
# kredit
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
df['alter'].nunique()
# Out:
# 53

# %%
df['alter'].max()
# Out:
# 75

# %%
df['hoehe'].max()
# Out:
# 18424

# %%
df['hoehe'].min()
# Out:
# 250

# %%
df.groupby('kredit')['alter'].mean()
# Out:
# kredit
# 0    33.96
# 1    36.22
# Name: alter, dtype: float64

# %%
df['telef'].value_counts()
# Out:
# telef
# 1    596
# 2    404
# Name: count, dtype: int64

# %%
df['kredit'].value_counts(normalize=True)
# Out:
# kredit
# 1    0.7
# 0    0.3
# Name: proportion, dtype: float64

# %% [markdown]
# We have 70% good and 30% bad

# %%
df.groupby('kredit')['hoehe'].mean()
# Out:
# kredit
# 0    3938.126667
# 1    2985.442857
# Name: hoehe, dtype: float64

# %%
df.groupby('kredit')['alter'].mean()
# Out:
# kredit
# 0    33.96
# 1    36.22
# Name: alter, dtype: float64

# %%
df.groupby('kredit')['hoehe'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='kredit'>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)
